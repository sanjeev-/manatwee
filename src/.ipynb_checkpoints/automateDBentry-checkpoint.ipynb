# %%
import numpy as np
import pickle
import pandas as pd
from sqlalchemy import create_engine
from dateutil import parser
import os, errno, sys

# %%
engine = create_engine('postgresql://sanjeev:Daconia4$@localhost/manatweedb')

# %%
users = pd.read_sql_table('twttr_twitteruser',engine)

# %%
users.head()
# Out:
#    id          name location category                        timestamp  \
# 0   1    TheTVBuffs     None   normal 2017-11-30 23:08:33.534243+00:00
# 1   2  VAsSuperior1     None   normal 2017-11-30 23:08:33.536597+00:00
# 2   3   Sevn_devilz     None   normal 2017-11-30 23:08:33.537871+00:00
# 3   4      kryst077     None   normal 2017-11-30 23:08:33.539092+00:00
# 4   5     Hodraghar     None   normal 2017-11-30 23:08:33.540409+00:00
#
#                            updated  slug
# 0 2017-11-30 23:08:33.534264+00:00  None
# 1 2017-11-30 23:08:33.536615+00:00  None
# 2 2017-11-30 23:08:33.537885+00:00  None
# 3 2017-11-30 23:08:33.539107+00:00  None
# 4 2017-11-30 23:08:33.540425+00:00  None

# %%
TV_PATH = '/home/ubuntu/cv/aerial/DeepNetsEO/DeepNetsForEO/nlp/site/src/utils/picklejar/TV_new.pickle'
with open(TV_PATH, 'rb') as handle:
    TV = pickle.load(handle)

# %%
TV.username.index = range(len(TV.username))

# %%
userspickles = pd.DataFrame(TV.username.unique(),index=range(len(TV.username.unique())))

# %%
usersdb = users.name

# %%
usersdb.head()
# Out:
# 0      TheTVBuffs
# 1    VAsSuperior1
# 2     Sevn_devilz
# 3        kryst077
# 4       Hodraghar
# Name: name, dtype: object

# %%
ds1 = set([ tuple(line) for line in userspickles.values.tolist()])
ds2a = [[x] for x in usersdb.values.tolist()]
ds2 = set([ tuple(line) for line in ds2a])
ds1.difference(ds2)
users_add=pd.DataFrame(list(ds1.difference(ds2)))

# %%
ds2a
# Out:
# [[u'TheTVBuffs'],
#  [u'VAsSuperior1'],
#  [u'Sevn_devilz'],
#  [u'kryst077'],
#  [u'Hodraghar'],
#  [u'mircoboh'],
#  [u'expxlliarmus'],
#  [u'cutietroyex'],
#  [u'hugon88'],
#  [u'Jrangel77'],
#  [u'Steven_Krimmel'],
#  [u'gersoningres'],
#  [u'WitDiary'],
#  [u'victororvikk'],
#  [u'fdkroom_104'],
#  [u'veepism'],
#  [u'JimJimdemario'],
#  [u'queenkrakowski'],
#  [u'LoveRunandPray'],
#  [u'jcorby7'],
#  [u'sydneyjanexo'],
#  [u'cazzlange'],
#  [u'itarjan'],
#  [u'Wolfapo'],
#  [u'hetalcb'],
#  [u'Styrbjorn'],
#  [u'Hooplaoly'],
#  [u'Patrick03NCIS'],
#  [u'Lowlow016'],
#  [u'Sugamama0071'],
#  [u'the4list'],
#  [u'bluerock1234'],
#  [u'carlolipsky'],
#  [u'dare_to_aditya'],
#  [u'sayo_oj'],
#  [u'kw1979'],
#  [u'NYMag'],
#  [u'franklin_mendez'],
#  [u'Noirello'],
#  [u'albertoapardo'],
#  [u'Matt_Th3_Hatter'],
#  [u'shop4charities'],
#  [u'eric_shinn'],
#  [u'Jilltension'],
#  [u'Osoiatama'],
#  [u'juliansage'],
#  [u'AlexG1348'],
#  [u'TaylorDLucas'],
#  [u'JaredMcGrath'],
#  [u'Thespiate'],
#  [u'GRTBOIRE'],
#  [u'badalsahiba'],
#  [u'dawnadaire'],
#  [u'NancySumner12'],
#  [u'4everWeirdo'],
#  [u'emilialuxa'],
#  [u'sheridorsey101'],
#  [u'BruceLebowski'],
#  [u'RollingStone'],
#  [u'nickbibby28'],
#  [u'britnygottalent'],
#  [u'luvscoconut'],
#  [u'averagehope'],
#  [u'MrChoboto'],
#  [u'marsiaj'],
#  [u'RogerPedactur'],
#  [u'sheerAhamed'],
#  [u'Wipeoutt31'],
#  [u'Serial_Optimist'],
#  [u'IanThinji'],
#  [u'dj_themes'],
#  [u'snoflakepersist'],
#  [u'svalentineplay'],
#  [u'BriSteirer'],
#  [u'vmalviya'],
#  [u'andersgeek'],
#  [u'bemo5000'],
#  [u'mbcogswell'],
#  [u'estheramma'],
#  [u'DennisPerkins5'],
#  [u'NY_Sweetie'],
#  [u'StevenM42574320'],
#  [u'TheBestivus'],
#  [u'Sepulcher67'],
#  [u'IsaacXYQ'],
#  [u'BreindelzRebel'],
#  [u'CulturessFS'],
#  [u'TriciaHastings3'],
#  [u'idreamofsully'],
#  [u'rieth_damon'],
#  [u'MattZ65'],
#  [u'DevilishHusky'],
#  [u'ssaywhatnow'],
#  [u'Jmylessmiles'],
#  [u'Trump2Dump'],
#  [u'trump_resigned'],
#  [u'Spiggitzfan'],
#  [u'VingaGjerstad'],
#  [u'NeoRenfield'],
#  [u'kathikruse'],
#  [u'farbav'],
#  [u'CrayKain'],
#  [u'impulseaffects'],
#  [u'nightowl97'],
#  [u'mzayfert'],
#  [u'ghazalairshad'],
#  [u'ResistGreed'],
#  [u'GamerGeekNews'],
#  [u'coyoteziongreen'],
#  [u'ephemeralobject'],
#  [u'NYCityQuaker'],
#  [u'cmerry'],
#  [u'Jenifur_96'],
#  [u'Hitandmisses4'],
#  [u'mujer_lg'],
#  [u'suenosdeuomi'],
#  [u'sroneal921'],
#  [u'PavanSurvi'],
#  [u'ColleenHolt20'],
#  [u'arquitetinha'],
#  [u'milehighcompany'],
#  [u'TylerHughs'],
#  [u'bekylou4jc'],
#  [u'Frank_Walle'],
#  [u'Lishanw'],
#  [u'jansterling7'],
#  [u'MyTVFamily'],
#  [u'barebones984'],
#  [u'pazesez'],
#  [u'GhayleNilesh'],
#  [u'Charvettebey'],
#  [u'covfefe02'],
#  [u'L188188'],
#  [u'FenrierArlius'],
#  [u'blueclick11'],
#  [u'M_Hamilton74'],
#  [u'chaarlyly'],
#  [u'MelmoMacdaffy'],
#  [u'IttoUsagi'],
#  [u'sidhu'],
#  [u'rachelbarbrass'],
#  [u'a23ryan'],
#  [u'baralheia'],
#  [u'Tanukitsune'],
#  [u'TheMarySue'],
#  [u'aGreenOhio'],
#  [u'Roddee'],
#  [u'sigantengkalem'],
#  [u'TheFunFinn'],
#  [u'GRJDigitalLife'],
#  [u'mayatcontreras'],
#  [u'sonpaks'],
#  [u'aakarkesarkar'],
#  [u'vmInMD'],
#  [u'KDSarge'],
#  [u'yuuichikun'],
#  [u'antidote4stress'],
#  [u'jesusalfar'],
#  [u'Mom2han8'],
#  [u'EdinaDebbie'],
#  [u'GeekInfoNow'],
#  [u'Dignan1981'],
#  [u'alejoalmanza02'],
#  [u'mosharafhmsj'],
#  [u'MsBrittanyMusic'],
#  [u'JordanDane'],
#  [u'b_a_kirsch'],
#  [u'leebren9'],
#  [u'Atwitisborn'],
#  [u'UPROXX'],
#  [u'ejkaboom'],
#  [u'Suburb_Flamingo'],
#  [u'ReneeLascala'],
#  [u'MaureenRamsden'],
#  [u'FMJohnson530'],
#  [u'LiveMike46'],
#  [u'PRoadrunner8776'],
#  [u'djbakey'],
#  [u'LadyEdeltraud'],
#  [u'NeedsC8H10N4O2'],
#  [u'HotShotAndy'],
#  [u'pearlsbaubles'],
#  [u'YahooEnt'],
#  [u'GloriaCBrooks'],
#  [u'YuxinHou'],
#  [u'RuthSorbello'],
#  [u'1Tequila234'],
#  [u'ksush73'],
#  [u'f1lthycoastie'],
#  [u'CSJJ2116'],
#  [u'tmogul_live'],
#  [u'hoosiemommy27'],
#  [u'CubbyPau'],
#  [u'kwiebke'],
#  [u'jskowall'],
#  [u'Njoyus1'],
#  [u'Deirdre10025Rad'],
#  [u'NoSheTwitNt'],
#  [u'ElixabethEgg'],
#  [u'nelmadman'],
#  [u'zunderwhelmed'],
#  [u'MaraJade_2017'],
#  [u'KayeJ'],
#  [u'Jat_APT'],
#  [u'waydebuonadonna'],
#  [u'unseenfilms'],
#  [u'smsasak'],
#  [u'RonaldXJT'],
#  [u'Betsy_Manning'],
#  [u'mr_jj_cakes'],
#  [u'LadsRAllRight'],
#  [u'hubchak'],
#  [u'PSuePrather'],
#  [u'powerinva'],
#  [u'MovieSlut'],
#  [u'DrnLr13'],
#  [u'Liuny'],
#  [u'Ronald__Rump'],
#  [u'JWillette1805'],
#  [u'NormalcyBias'],
#  [u'EricJarrett2'],
#  [u'geeweed39'],
#  [u'OuiserB_NC'],
#  [u'MaryInTheRoses'],
#  [u'Mcham83314004'],
#  [u'ModaMags'],
#  [u'Dooftomdow'],
#  [u'aunt_bitchyb'],
#  [u'JustAintNormal'],
#  [u'lisa_pearl_'],
#  [u'mininurse'],
#  [u'lawbibliophile'],
#  [u'Paf000001'],
#  [u'standforself'],
#  [u'winkingvenus'],
#  [u'Nikluk'],
#  [u'my2twh'],
#  [u'HoneyChild_OZ'],
#  [u'jj_poitras'],
#  [u'Toni_Raelin'],
#  [u'CitizenKayS'],
#  [u'Pithygirl'],
#  [u'mediagonebad'],
#  [u'52NDINBXSUCKS'],
#  [u'wendegarrison'],
#  [u'riledup1'],
#  [u'NoelMacNeal'],
#  [u'20indicia'],
#  [u'geoffreygibson1'],
#  [u'floralgarden'],
#  [u'KentabooRex'],
#  [u'WelshGrumpyGit'],
#  [u'jks89ky'],
#  [u'back2memphis'],
#  [u'MaryAnneSherry'],
#  [u'HLSudler'],
#  [u'Dry_Observer'],
#  [u'SharonGjertsen'],
#  [u'underscore_pete'],
#  [u'UnSkelator'],
#  [u'RickReut'],
#  [u'Amber31422'],
#  [u'DoggieDog'],
#  [u'oscararguijojr'],
#  [u'unionmindbody'],
#  [u'MimiLeroch'],
#  [u'Leeleefix'],
#  [u'BigBarsTweetBox'],
#  [u'Mirsathia'],
#  [u'desole'],
#  [u'skynet_dreams'],
#  [u'xinanorris'],
#  [u'NealKayhack'],
#  [u'Marknovakusa'],
#  [u'FallenShutter'],
#  [u'mhatrerohan1990'],
#  [u'rbi_luna'],
#  [u'shychobit'],
#  [u'omer1kacan'],
#  [u'jongurutz'],
#  [u'hawknut888'],
#  [u'Mandari25733571'],
#  [u'MyFriendAli'],
#  [u'JoeJoeWitty'],
#  [u'janetjonesbann'],
#  [u'SelenaQuinzel'],
#  [u'emma_bobo_'],
#  [u'geilerstrumpf'],
#  [u'Buddhababy10'],
#  [u'Bravo_Avo_Cado'],
#  [u'SusanMumpowerSp'],
#  [u'kenr276'],
#  [u'KraziliaLove'],
#  [u'k86404'],
#  [u'LJMaggie_Author'],
#  [u'espimandi'],
#  [u'hoopen_mark'],
#  [u'cwseigworth'],
#  [u'familygrowing1'],
#  [u'yenaaldlooskii'],
#  [u'mhathman'],
#  [u'tapati'],
#  [u'jajohn1984'],
#  [u'avierkirm'],
#  [u'Lyna_LV'],
#  [u'chmayer'],
#  [u'DarylDancy'],
#  [u'lilsliceofcraze'],
#  [u'AllaRayofLight'],
#  [u'adeebfarhat'],
#  [u'randyprine'],
#  [u'Trishamott'],
#  [u'SpryVioletta'],
#  [u'SaithFigueroa8'],
#  [u'rebeccaaweber'],
#  [u'_trancybrat_'],
#  [u'jatrix3000'],
#  [u'tacomadan'],
#  [u'Barbiewithatude'],
#  [u'Dre_DuNbar'],
#  [u'jesseleefulton'],
#  [u'ResistCentral'],
#  [u'barbaragordcn'],
#  [u'DoorWay2Fandom'],
#  [u'rosie_soto1998'],
#  [u'AriDelfino'],
#  [u'iamrachelwolf'],
#  [u'whitneymorfitt'],
#  [u'Angryreddog'],
#  [u'buzzyngabe'],
#  [u'GloYa001'],
#  [u'Mr_Rhapsodist'],
#  [u'SharonWeller1'],
#  [u'pgfallen'],
#  [u'C0rporateMerica'],
#  [u'rossleslie'],
#  [u'CarrosDeals'],
#  [u'maverickvogt'],
#  [u'wendywoodarling'],
#  [u'MFinizza'],
#  [u'GillianBagwell'],
#  [u'GGbudhrani'],
#  [u'MooreSaiyan'],
#  [u'AGFattal'],
#  [u'1nationofdom'],
#  [u'nikizgzg'],
#  [u'RaghaviSakpal'],
#  [u'perfectlyMessy'],
#  [u'Cancun771'],
#  [u'DJShereKhan'],
#  [u'monica_watson14'],
#  [u'auntislandshell'],
#  [u'hitmeister1'],
#  [u'singlepayer'],
#  [u'masg66'],
#  [u'jenprim60'],
#  [u'mooncove'],
#  [u'BradSabbath'],
#  [u'flognarde'],
#  [u'Rubix510'],
#  [u'deanna_woolston'],
#  [u'delictum'],
#  [u'priyology'],
#  [u'Trexrexrex27'],
#  [u'Steffi_955'],
#  [u'siristone'],
#  [u'emerson_jessy'],
#  [u'CJTUCKERTRUPAT'],
#  [u'msalanie'],
#  [u'AJoyForever83'],
#  [u'RAM_0629'],
#  [u'MsChristelleGo'],
#  [u'hilurrree'],
#  [u'Scotty_Did'],
#  [u'awfarquer'],
#  [u'Reme_GripHeart'],
#  [u'j_writes_daily'],
#  [u'Vickie0612'],
#  [u'PolishPeddler'],
#  [u'sbaracadau'],
#  [u'JCVanTam41'],
#  [u'jestikon'],
#  [u'ricswartzlander'],
#  [u'DorothySmith11'],
#  [u'BlogLaunch'],
#  [u'ThePansyBastard'],
#  [u'katylied67'],
#  [u'SuperPonyBolt'],
#  [u'YodaEconomics'],
#  [u'MsLisaBaby'],
#  [u'shep3676'],
#  [u'ArtistLiquid99'],
#  [u'ilovejohnoliver'],
#  [u'SummoPlex'],
#  [u'dakg666'],
#  [u'LIVINGDEADGRRL2'],
#  [u'Quinn85M'],
#  [u'chrysicat'],
#  [u'devhax_jill'],
#  [u'April5886'],
#  [u'treedoctor5'],
#  [u'ManOfMadness'],
#  [u'Trojangoddess'],
#  [u'Bruddahlekil'],
#  [u'AquariumOfTruth'],
#  [u'_FallingGrace'],
#  [u'sammy__superman'],
#  [u'wtf_imtooold'],
#  [u'DaleF3'],
#  [u'WeeeeeSquirrel'],
#  [u'godofbiscuits79'],
#  [u'LorrieLife'],
#  [u'RamasScreen'],
#  [u'Ryan_Garcia99'],
#  [u'rgowshik'],
#  [u'CricketArt67'],
#  [u'jill_woodie'],
#  [u'janeeucraft'],
#  [u'MaesterMercy'],
#  [u'ABadDreamMaybe'],
#  [u'kathrynswartz'],
#  [u'slmonsaysjake'],
#  [u'MissNikki119'],
#  [u'RicknShira'],
#  [u'joycelynn1017'],
#  [u'PacificBayley'],
#  [u'mlkechan9'],
#  [u'Janeygilly'],
#  [u'Anniefromkansas'],
#  [u'xlegendarypete'],
#  [u'atticuskim'],
#  [u'Wilphred'],
#  [u'behepchat'],
#  [u'joeheyming'],
#  [u'kkp444'],
#  [u'thepha'],
#  [u'SLChotei'],
#  [u'MediatedReality'],
#  [u'RikDaddy'],
#  [u'FormersportsMOM'],
#  [u'ua9grr6m'],
#  [u'RiseUpAbove'],
#  [u'DeliaMacD1'],
#  [u'jene_lara'],
#  [u'CalebTRB'],
#  [u'redheadgrl04'],
#  [u'supernovanGirl'],
#  [u'duj8SCsvQwoR01H'],
#  [u'xotrlppyxoxo'],
#  [u'Cherberrie72'],
#  [u'xexet0p'],
#  [u'ferdball'],
#  [u'goaconstrictor'],
#  [u'3GNITGNAG8'],
#  [u'sammitani'],
#  [u'mandipandi303'],
#  [u'MichelleD5041'],
#  [u'bamayomama'],
#  [u'ArredondoJalme'],
#  [u'fejimanz'],
#  [u'TrumpWatchNews'],
#  [u'TabberAnn'],
#  [u'jitterymoose'],
#  [u'Eric_John'],
#  [u'cdzSjouwelke'],
#  [u'VictorOmoayo'],
#  [u'UNrealTara'],
#  [u'paulburkhardt53'],
#  [u'Cheenisms'],
#  [u'kateacosta5'],
#  [u'nmomminator'],
#  [u'timmthelen'],
#  [u'RhondaR85636004'],
#  [u'ilovecheeseblt'],
#  [u'JaneJJustice'],
#  [u'JamesDailyTV'],
#  [u'padakitty'],
#  [u'willhitell'],
#  [u'thewhiteguy_'],
#  [u'StarvingWriter_'],
#  [u'tamilu40'],
#  [u'3rdWorldFunktry'],
#  [u'fxnkls'],
#  [u'Rachel_McRea'],
#  [u'Eisentower30'],
#  [u'JoJo_Chanel'],
#  [u'geewlzscarlett'],
#  [u'JacobDavison_'],
#  [u'bumgarls'],
#  [u'marybeth_lawson'],
#  [u'pchhabra'],
#  [u'parkertheghost'],
#  [u'michaelstevenmc'],
#  [u'chaser1066'],
#  [u'sneakyriki'],
#  [u'jcasap'],
#  [u'mariaro78915887'],
#  [u'MarieFr12579649'],
#  [u'duganchen'],
#  [u'WeLoveLSSC'],
#  [u'cbn2'],
#  [u'Beansrdone'],
#  [u'cpsloal'],
#  [u'dmgillis'],
#  [u'iowamadenet'],
#  [u'cbadattorney'],
#  [u'DubyaWife'],
#  [u'DarkerThanBrad'],
#  [u'1DLowther'],
#  [u'ChildlikeVision'],
#  [u'DanInPittsburgh'],
#  [u'DeirdreOakland'],
#  [u'paula_mceneaney'],
#  [u'chrishesed'],
#  [u'debyou5'],
#  [u'Toddster1985'],
#  [u'ToddWarring'],
#  [u'eggstartweets'],
#  [u'liberalgirl4'],
#  [u'shercares'],
#  [u'LemonKnapp'],
#  [u'marildeo'],
#  [u'ScottLNicolson'],
#  [u'gillovnot'],
#  [u'Uzulena'],
#  [u'write2bheard1'],
#  [u'Jay_3085'],
#  [u'Kane007'],
#  [u'ZenMasterRham'],
#  [u'rural_juror'],
#  [u'Aragall'],
#  [u'TomiBaird'],
#  [u'HOPE4THE_FUTURE'],
#  [u'mega_____worth'],
#  [u'caseytoussaint1'],
#  [u'dawnlyndel'],
#  [u'ThyGeekGoddess'],
#  [u'LawrenceTeller'],
#  [u'LLSHMDfn2'],
#  [u'PaulaChertok'],
#  [u'DianeAzarian'],
#  [u'spennington33'],
#  [u'CBJOHNSON143'],
#  [u'viennasausage08'],
#  [u'GeorginaTennant'],
#  [u'yungpreet'],
#  [u'ScorpionqueenTX'],
#  [u'KathyNiece'],
#  [u'CarterMattTV'],
#  [u'uncannynerf'],
#  [u'KatieLS77'],
#  [u'selliottbiology'],
#  [u'FPMartinelli27'],
#  [u'DonnaSellers'],
#  [u'PrezHillary17'],
#  [u'iamxlr8r'],
#  [u'jdj9930'],
#  [u'DrGMLaTulippe'],
#  [u'LisaNOTsam'],
#  [u'danielle92118'],
#  [u'alioshin'],
#  [u'TheSteamer'],
#  [u'lauraMcc1422'],
#  [u'Catherine000Gr8'],
#  [u'djgslr'],
#  [u'TiVoMHA'],
#  [u'retiringart'],
#  [u'pirateguy815'],
#  [u'toffeebugs'],
#  [u'jayceebabi'],
#  [u'GabeIglesia'],
#  [u'DeweyBratcher'],
#  [u'jacksm39'],
#  [u'factsandrants'],
#  [u'5crews'],
#  [u'1p8774'],
#  [u'wildjaden'],
#  [u'EhYoJackyBoy'],
#  [u'Bellalindafox'],
#  [u'RavenEyz'],
#  [u'redheadedwitch'],
#  [u'AngelaCucciaDay'],
#  [u'chilepeppermama'],
#  [u'vicarious24'],
#  [u'SuperRewinder'],
#  [u'ladnerdude'],
#  [u'RaradraF'],
#  [u'gentIyweeps'],
#  [u'anyarally'],
#  [u'gleneyo2'],
#  [u'caesarmurillo'],
#  [u'juanAKAdonjuan'],
#  [u'olikolokolo'],
#  [u'Scow0857'],
#  [u'LSalome2'],
#  [u'floridaroom62'],
#  [u'vinnland1789'],
#  [u'JitanHawkeye'],
#  [u'ReyAbiNahed'],
#  [u'suburbandwarf'],
#  [u'Rajas40'],
#  [u'batoutofmel'],
#  [u'Bambi_CB'],
#  [u'Lee672011'],
#  [u'jmoraga1'],
#  [u'bleachedbrain'],
#  [u'Journeyman15'],
#  [u'ahnahleesah'],
#  [u'NicoleW_Mac'],
#  [u'Lyd2986'],
#  [u'DlSCORD'],
#  [u'JaredSchnabl'],
#  [u'ByrdMan1328'],
#  [u'JessesLaw'],
#  [u'ellearee'],
#  [u'MattCarterMedia'],
#  [u'kbeninato'],
#  [u'LadyBirdOsprey'],
#  [u'williemoeday'],
#  [u'TheGlorybound'],
#  [u'Donny_M91'],
#  [u'jooblee'],
#  [u'cvillegirl01'],
#  [u'Lightecojak'],
#  [u'samnjacksmom'],
#  [u'Galileo908'],
#  [u'Mikeyeddy'],
#  [u'JeaSusan'],
#  [u'goodgonegeek'],
#  [u'robertemilem'],
#  [u'Adipositivity'],
#  [u'viequesdynamo'],
#  [u'rego_arego896'],
#  [u'theaveragemovie'],
#  [u'IamGoldie22'],
#  [u'TheLastLinda'],
#  [u'ExtrovertedSide'],
#  [u'EarlLipphardtJr'],
#  [u'debv219'],
#  [u'jicastillo'],
#  [u'Tamecat1'],
#  [u'BlexClex'],
#  [u'witchelli'],
#  [u'LaDisputeTouche'],
#  [u'GreenChileAdict'],
#  [u'gabrielmartinez'],
#  [u'ElRobinero'],
#  [u'SirKingofGifs'],
#  [u'kimmiekat81'],
#  [u'MatManz'],
#  [u'jmayDET'],
#  [u'musicaljunkie96'],
#  [u'Red_Peg_in_SC'],
#  [u'sleepyeepee'],
#  [u'jenarific'],
#  [u'mzvxb'],
#  [u'Frojoho'],
#  [u'perolikeidgaf'],
#  [u'Goofyfan_Chuck'],
#  [u'Kakashi316'],
#  [u'saint_even'],
#  [u'LakeEstep'],
#  [u'thegassyunicorn'],
#  [u'CousinsWatchTV'],
#  [u'KeithMcC29'],
#  [u'Keepin_Current'],
#  [u'Haunt1013'],
#  [u'GallagherRadio'],
#  [u'GlamBelle9'],
#  [u'hullobacon'],
#  [u'BlueGenWhite'],
#  [u'nevaRWilliams'],
#  [u'ForeJefferson'],
#  [u'CurtTalksTV'],
#  [u'carlospugapala1'],
#  [u'TripleThreatCLE'],
#  [u'hotels4charity'],
#  [u'greensoci'],
#  [u'BrandedGlobal'],
#  [u'JProwess'],
#  [u'TVTracksRadio'],
#  [u'tvrecapsreviews'],
#  [u'Torres3____'],
#  [u'filehoot'],
#  [u'VinoCaPisco'],
#  [u'MichaelCrouch3r'],
#  [u'stockhunter8'],
#  [u'7m14WuAwaFfSz7r'],
#  [u'worldbandage'],
#  [u'Meem618'],
#  [u'fashiongreens'],
#  [u'AutomationRobot'],
#  [u'johnblessing00'],
#  [u'medjak40'],
#  [u'bouffizms'],
#  [u'TVMaury'],
#  [u'joshrubinsays'],
#  [u'dangergirl101'],
#  [u'pubada'],
#  [u'OfficialGiampy'],
#  [u'TheNewDemocrat'],
#  [u'wordpressaff'],
#  [u'benzm001'],
#  [u'travelaff'],
#  [u'jamfinlay'],
#  [u'AJMernone'],
#  [u'greenblogtalks'],
#  [u'Redrum_of_Crows'],
#  [u'TravisRuger'],
#  [u'AnthonyShannon2'],
#  [u'MOOCHIE_BOOCHES'],
#  [u'buuubble_gum'],
#  [u'jessicamdefina'],
#  [u'SpeakatheDevil'],
#  [u'andiminga'],
#  [u'growingsocials'],
#  [u'MaryJenGreen'],
#  [u'Eve_Venn'],
#  [u'LibDemLaura'],
#  [u'sound_of_sirens'],
#  [u'ips_journal'],
#  [u'honzasterba'],
#  [u'ChrisPeristeri'],
#  [u'JamesMoyner'],
#  [u'billrantz'],
#  [u'noahgreenNBA'],
#  [u'MgCaceres'],
#  [u'Awwldrinoow'],
#  [u'awaken_pr'],
#  [u'gailfs'],
#  [u'Scollasu'],
#  [u'jenmovies'],
#  [u'jesterkiller667'],
#  [u'ArtistPresents'],
#  [u'_iamvikram'],
#  [u'RAODEVYANI'],
#  [u'citybecamesound'],
#  [u'_Real_List'],
#  [u'HFRevolution'],
#  [u'paolo_sf'],
#  [u'SamuelJDay_'],
#  [u'CarolynNYC'],
#  [u'viceview51'],
#  [u'a_d_31'],
#  [u'AnnCarters'],
#  [u'drfarmertx'],
#  [u'UnknownArt84'],
#  [u'PositiveVinny'],
#  [u'Sisterwriter'],
#  [u'_SergioDasNeves'],
#  [u'JohnReganQS'],
#  [u'Sliebs69'],
#  [u'krislakin'],
#  [u'MotykaJessica'],
#  [u'TheRiverWanders'],
#  [u'davidclark'],
#  [u'CarrawayTiia'],
#  [u'GeorgeMcCollum'],
#  [u'trumpsconcious'],
#  [u'saxxysavannah'],
#  [u'antonis7lowbap'],
#  [u'kanekos69'],
#  [u'micahmclain'],
#  [u'ClevelandNewDay'],
#  [u'IrishPatty54'],
#  [u'YazzySaz88'],
#  [u'Joelh56'],
#  [u'JohnCzer1'],
#  [u'CarlBlazeLIVE'],
#  [u'Donnell1Therese'],
#  [u'MisterCrisp'],
#  [u'marvymuse'],
#  [u'Senti_Carina'],
#  [u'ricottajpie'],
#  [u'marcelewals'],
#  [u'RRN3'],
#  [u'catwoman1979'],
#  [u'TheTweetingBat'],
#  [u'TiMEoFPoSTiNG'],
#  [u'SunkanmiShams'],
#  [u'walegates'],
#  [u'modernjumpsuit'],
#  [u'KazGui'],
#  [u'OklahomaWise'],
#  [u'ay_fletch'],
#  [u'AlyssaRTyra'],
#  [u'APPLESToNEPiX'],
#  [u'rahul_sharma9'],
#  [u'sckitupbuttercp'],
#  [u'gupmich'],
#  [u'pastles_live'],
#  [u'ThoughtsofRS'],
#  [u'sassy_nach'],
#  [u'ThePashaB'],
#  [u'yashsoni07'],
#  [u'Smurfbate'],
#  [u'RLoftis4'],
#  [u'JETBallin'],
#  [u'sheryl_monk'],
#  [u'annes_plan'],
#  [u'ssgoku129'],
#  [u'LindseyHempton'],
#  [u'james_w_allen'],
#  [u'monalisathefox'],
#  [u'pnaegelySTS'],
#  [u'rscottwhite2'],
#  [u'AlexHenao87'],
#  [u'johnpgatta'],
#  [u'hagardwallace'],
#  [u'BoffleSpoffle'],
#  [u'TheLifeofGiGi'],
#  [u'dannysullivan'],
#  [u'ashleydixon'],
#  [u'sweetjenn84'],
#  [u'Wendy2409'],
#  [u'MrsJekyllsHyde'],
#  [u'MarySenate2018'],
#  [u'WiseWarrior69'],
#  [u'angienic715'],
#  [u'ss7goddess'],
#  [u'BagiraMel'],
#  [u'lmgllg'],
#  [u'KSuzanneG'],
#  [u'StylistLindseyB'],
#  [u'dialatricia'],
#  [u'thenamescliff'],
#  [u'RonDonson'],
#  [u'ashleyjperna'],
#  [u'downlowdude'],
#  [u'tru_master'],
#  [u'XanderrFFXI'],
#  [u'DianeCHarper'],
#  [u'madebycarol'],
#  [u'PaulJTortoraJr'],
#  [u'prussedouce'],
#  [u'NappySamurai'],
#  [u'giantmanish'],
#  [u'JennPancorbo'],
#  [u'_teagaaan'],
#  [u'campkeesley'],
#  [u'book_club'],
#  [u'EvilStarfish23'],
#  [u'SilipigniMario'],
#  [u'xCarlosEMendez'],
#  [u'WolfGirl_84'],
#  [u'indygeoff'],
#  [u'BlindDrilling'],
#  [u'tinadybvik'],
#  [u'Rokyprch'],
#  [u'osgood_laurie'],
#  [u'Queen_B_TRB'],
#  [u'DrBillSpeirs'],
#  [u'mkvermette'],
#  [u'style4charities'],
#  [u'DeanBebout'],
#  [u'itsmelikewoah'],
#  [u'CherylRutledg17'],
#  [u'mikey_mike_md'],
#  [u'phaeuser'],
#  [u'TommyCody'],
#  [u'dprite1'],
#  [u'ju2thalee'],
#  [u'BooksHockey'],
#  [u'msol88'],
#  [u'NLinnane'],
#  [u'EmergingStrong'],
#  [u'HelanMBack'],
#  [u'NotRedy2MakNice'],
#  [u'KRCCT62'],
#  [u'MamasSwerveBall'],
#  [u'Kgrogz'],
#  [u'melscottsketch'],
#  [u'writer_unknown1'],
#  [u'Jeannie_Hartley'],
#  [u'Jay__Perez08'],
#  [u'Grandma_Shelia'],
#  [u'_JaredClarkson'],
#  [u'free4followers'],
#  [u'SmashingTweet'],
#  [u'SaraParker411'],
#  [u'JasonBelyea'],
#  [u'sugar_yespleaz'],
#  [u'putln2'],
#  [u'mayflower_gal'],
#  [u'PeggyDavisLA'],
#  [u'dee_ander7'],
#  [u'Gen_Ago'],
#  [u'Su_Spencer'],
#  [u'wickedprincess'],
#  [u'DawnDesisto'],
#  [u'99ermikeb'],
#  [u'inasequoia'],
#  [u'rnelson0'],
#  [u'sammbarre'],
#  [u'Mosh'],
#  [u'thomasjvn'],
#  [u'MallieRydzik'],
#  [u'_skyfall92'],
#  [u'colleenmd'],
#  [u'dhancock_110'],
#  [u'KitKatDiaries14'],
#  [u'DamalinDamalin'],
#  [u'stylish_in_dc'],
#  [u'Grnsoccershoe'],
#  [u'brenda_lynn82'],
#  [u'BananaNunChucks'],
#  [u'LucasLascivious'],
#  [u'SamDavidJohn'],
#  [u'drancher'],
#  [u'lisa_gruni'],
#  [u'neilnicholson'],
#  [u'blackoween'],
#  [u'aminpakseresht'],
#  [u'marcifromCO'],
#  [u'Paes'],
#  [u'Jbastardov'],
#  [u'dailyweeklypost'],
#  [u'1010peggylane'],
#  [u'brendan_fc'],
#  [u'TheresaZphotoz'],
#  [u'catadams03'],
#  [u'JLStep3'],
#  [u'ChesterSColbert'],
#  [u'thejollycorpse'],
#  [u'pplmakemecrazy'],
#  [u'niftyjames'],
#  [u'PhelpsKole'],
#  [u'pcoston1'],
#  [u'Emiloberg1'],
#  [u'ben_nolte'],
#  [u'witsandwhine'],
#  [u'dale_callihan'],
#  [u'AliMohummadSyed'],
#  [u'Sabi_MMJ_guide'],
#  [u'2Freelancer'],
#  [u'Urplebandit'],
#  [u'shotakincha'],
#  [u'vesna2p'],
#  [u'LVCzeca'],
#  [u'SkyIreland'],
#  [u'erichristiansen'],
#  [u'patientxzero'],
#  [u'neozeitgeist'],
#  [u'TNorlander'],
#  [u'nate_ruff'],
#  [u'MichelleBelleMN'],
#  [u'SamMerwah1996'],
#  [u'pattykvilla'],
#  [u'GaryHPhillips'],
#  [u'COPEstar69'],
#  [u'InkedDoll'],
#  [u'RevEspejo'],
#  [u'NurseMikeGreen'],
#  [u'theGuruWithin'],
#  [u'jgdude'],
#  [u'HenryRBishop'],
#  [u'ram_nagi'],
#  [u'1chefdiva'],
#  [u'dirtyyankee83'],
#  [u'JohnGra30221745'],
#  [u'mmalfitano1'],
#  [u'micfic'],
#  [u'Dansalvez'],
#  [u'_ezgonmike'],
#  [u'LigiaEscobarr'],
#  [u'HALO172'],
#  [u'roadpartner'],
#  [u'CamilleAlsup'],
#  [u'theOnlyNicekid'],
#  [u'Jamkai'],
#  [u'Sabiduria_LuAw'],
#  [u'FindingNiro'],
#  [u'MaryTroupe7'],
#  [u'pit12pit'],
#  [u'juanadominpe'],
#  [u'mauricio_o_reis'],
#  [u'big_hutchings'],
#  [u'AlexandruSCT'],
#  [u'AngelSweetie2'],
#  [u'skyatlantic'],
#  [u'soapfanfiction'],
#  [u'mmpadellan'],
#  [u'zell1819'],
#  [u'nancyneff2'],
#  [u'mc_middle'],
#  [u'JohnnyFirecloud'],
#  [u'Luucija_S'],
#  [u'Pabs_delToro9'],
#  [u'NycAnarchy'],
#  [u'Sold_My_S0ul'],
#  [u'x5reviews'],
#  [u'SoulStealer2011'],
#  [u'mcat128'],
#  [u'Edgewood1111'],
#  [u'glenkrisch'],
#  [u'Burleytommy'],
#  [u'dy4colts'],
#  [u'jmanzels'],
#  [u'bgmckeown'],
#  [u'CatherineVasso1'],
#  ...]

# %%
users_add
# Out:
#                      0
# 0             OsSastre
# 1           zioringhio
# 2           karmitage8
# 3              Rayllex
# 4          Eve39814641
# 5         MyNameIs_DRE
# 6       jacklondonjack
# 7             mamaezzj
# 8             kaisling
# 9           abicrulley
# 10            JAG1Prod
# 11        SeymourSnott
# 12         reveresbest
# 13       kevinlavelle5
# 14        CielBraddock
# 15      ImagineGiselle
# 16       crystalabritt
# 17          TrevyTrev5
# 18         beatnikprof
# 19      ShirleyMcQueen
# 20           bahenerys
# 21             __RLC__
# 22         JPgrooves10
# 23     HassanH68577272
# 24     OiltheIcePrince
# 25         trecoolnips
# 26          RainKewkew
# 27         sandra91767
# 28          JoeDiMauro
# 29          slave_eric
# ...                ...
# 34339       lordvarys2
# 34340         spin1038
# 34341    miguelredders
# 34342   SudheshGiriyan
# 34343  Gnightheartache
# 34344  tylerchronicles
# 34345       Usshak2187
# 34346       feschnando
# 34347    Enrique000009
# 34348     StealingCake
# 34349   paulgreenstone
# 34350      DisneyPoney
# 34351    Aaron_J_Green
# 34352       Sullivino_
# 34353        bellzytbh
# 34354    samanthaone22
# 34355   sowrongitsjohn
# 34356          16_by_9
# 34357      CharlieBNic
# 34358   fredypasghetti
# 34359     miss_tuckles
# 34360        Patpinto1
# 34361        Nswartz64
# 34362     wonderwally_
# 34363       ItsKItoYOU
# 34364        ban_10000
# 34365  BigDataScience3
# 34366          _N3sser
# 34367       _Marinakaa
# 34368      CamilleSmtt
#
# [34369 rows x 1 columns]

# %%
def add_df(tablename):
    engine = create_engine('postgresql://sanjeev:Daconia4$@localhost/manatweedb')
    db = pd.read_sql_table(tablename,engine)
    TV_PATH = '/home/ubuntu/cv/aerial/DeepNetsEO/DeepNetsForEO/nlp/site/src/utils/picklejar/TV_new.pickle'
    with open(TV_PATH, 'rb') as handle:
        TV = pickle.load(handle)
    if tablename=='twttr_twitteruser':
        TV.username.index = range(len(TV.username))
        userspickles = pd.DataFrame(TV.username.unique(),index=range(len(TV.username.unique())))
        userdb = db.name
        ds1 = set([ tuple(line) for line in userspickles.values.tolist()])
        ds2a = [[x] for x in userdb.values.tolist()]
        ds2 = set([ tuple(line) for line in ds2a])
        ds1.difference(ds2)
        users_add=pd.DataFrame(list(ds1.difference(ds2)))
        return users_add
    if tablename=='twttr_twittershow':
        TV.show.index = range(len(TV.show))
        showspickles = pd.DataFrame(TV.show.unique(),index=range(len(TV.show.unique())))
        showdb = db.name
        ds1 = set([ tuple(line) for line in showpickles.values.tolist()])
        ds2a = [[x] for x in showdb.values.tolist()]
        ds2 = set([ tuple(line) for line in ds2a])
        ds1.difference(ds2)
        shows_add=pd.DataFrame(list(ds1.difference(ds2)))
        return shows_add
    if tablename=='twttr_twitternetwork':
        TV.ntwk.index = range(len(TV.ntwk))
        ntwkpickles = pd.DataFrame(TV.ntwk.unique(),index=range(len(TV.ntwk.unique())))
        ntwkdb = db.name
        ds1 = set([ tuple(line) for line in userspickles.values.tolist()])
        ds2a = [[x] for x in ntwkdb.values.tolist()]
        ds2 = set([ tuple(line) for line in ds2a])
        ds1.difference(ds2)
        ntwk_add=pd.DataFrame(list(ds1.difference(ds2)))
        return ntwk_add

# %%
add_df('twttr_twitteruser')
# Out:
# 0             TheTVBuffs
# 1           VAsSuperior1
# 2            Sevn_devilz
# 3               kryst077
# 4              Hodraghar
# 5               mircoboh
# 6           expxlliarmus
# 7            cutietroyex
# 8                hugon88
# 9              Jrangel77
# 10        Steven_Krimmel
# 11          gersoningres
# 12              WitDiary
# 13          victororvikk
# 14           fdkroom_104
# 15               veepism
# 16         JimJimdemario
# 17        queenkrakowski
# 18        LoveRunandPray
# 19               jcorby7
# 20          sydneyjanexo
# 21             cazzlange
# 22               itarjan
# 23               Wolfapo
# 24               hetalcb
# 25             Styrbjorn
# 26             Hooplaoly
# 27         Patrick03NCIS
# 28             Lowlow016
# 29          Sugamama0071
#               ...
# 63405            makgyva
# 63406        jbangssalon
# 63407           M16MOLLY
# 63408          noturbine
# 63409      kendralawson_
# 63410    NWProfREMolalla
# 63411    Blum_RealEstate
# 63412       windwatchorg
# 63413       SPUAthletics
# 63414        PeacocksWBB
# 63415         LohnesMary
# 63416         DrGorczyca
# 63417        NewsFromSPI
# 63418    charl0tter0bs0n
# 63419           S_arahah
# 63420          Bless_NYC
# 63421        Armygirl3ID
# 63422      prisciila1239
# 63423    SuzetteBoudreau
# 63424    SalemPoliceDept
# 63425             SilkyC
# 63426     timclearyprops
# 63427      jpihealthcare
# 63428    climatesolution
# 63429       CourtneyFavs
# 63430    angelavanpatten
# 63431    Leonard_Higgins
# 63432           HMSJJobs
# 63433        SheaGDurkin
# 63434    cdecoratingidea
# Name: name, Length: 63435, dtype: object
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-67-d2f739ab2d59> in <module>()
# ----> 1 add_df('twttr_twitteruser')
#
# <ipython-input-66-fcc292282d89> in add_df(tablename)
#      12         ds1 = set([ tuple(line) for line in userspickles.values.tolist()])
#      13         ds2a = [[x] for x in db.values.tolist()]
# ---> 14         ds2 = set([ tuple(line) for line in ds2a])
#      15         ds1.difference(ds2)
#      16         users_add=pd.DataFrame(list(ds1.difference(ds2)))
#
# TypeError: unhashable type: 'list'
